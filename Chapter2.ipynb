# %%
# !git config --global user.name 'Hanni Grace Villa'
# !git config --global user.email 'hannigrace.villa@students.isatu.edu.ph'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Villa/PythonEnvi_Villa
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Villa/PythonEnvi_Villa

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Villa/PythonEnvi_Villa

# %%
ls
# Out:
# Chapter2.ipynb  hanni_env/  IS110_repo_Villa/  requirements.txt

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: hanni
# Hello hanni

# %%
Hours = float(input("Enter Hours: "))
Rate = float(input("Enter Rate: "))
Pay = float(Hours*Rate)
print("Pay: ", Pay)
# Out:
# Enter Hours: 5
# Enter Rate: 100
# Pay:  500.0

# %%
width = 17
height = 12.0

print(width // 2, type (width //2))
print(width / 2.0, type (width / 2.0))
print(height / 3, type (width / 3))
print(1+2*5, type (1+2*5))
# Out:
# 8 <class 'int'>
# 8.5 <class 'float'>
# 4.0 <class 'float'>
# 11 <class 'int'>

# %%
number = int(input("Enter a number: "))
square = number*number
print("The square of ", number, "is", square)
# Out:
# Enter a number: 60
# The square of  60 is 3600

# %%
Celsius = float(input("Enter a Celsius: "))
Fahrenheit = (Celsius*9/5)+32
print("Fahrenheit", Fahrenheit)
# Out:
# Enter a Celsius: 36
# Fahrenheit 96.8

# %%
ls
# Out:
# Chapter2.ipynb  hanni_env/  IS110_repo_Villa/  requirements.txt  world.py
